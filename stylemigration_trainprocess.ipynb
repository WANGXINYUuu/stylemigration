# %% [markdown]
# ### 数据集结构目录如下所示

# %%
# 将压缩包文件进行解压
# !unzip -o data/Fortnite2PUBG.zip -d data/Fortnite2PUBG/

# %%
'''
./data/Fortnite2PUBG/Fortnite2PUBG
                        ├── testA
                        │   └── XXX.jpg
                        ├── testB
                        │   └── XXX.jpg
                        ├── trainA
                        │   └── XXX.jpg
                        └── trainB
                            └── XXX.jpg
                            
其中，A为堡垒之夜(Fortnite)游戏画面，B为绝地求生(PUBG)游戏画面
'''

# %% [markdown]
# 以上"Fortnite2PUBG"数据集为自制数据集，若想自己训练模型，需根据自己需求按照上述数据集结构目录配置自己的数据集。下面是openmmlab提供的用于训练"梵高转照片"模型的配置文件，自行下载后对配置文件中的内容进行以下几点修改：
# + domain_a的名字修改为自己数据集中A域的名字
# + domain_b的名字修改为自己数据集中B域的名字
# + dataroot修改为自己数据集所在的目录
# + exp_name修改为自己实验的名字

# %%
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/cyclegan_lsgan_resnet_in_facades_b1x1_80k_vangogh2photo.py -O configs/cyclegan/cyclegan_lsgan_resnet_in_facades_b1x1_80k_vangogh2photo.py

# %% [markdown]
# ### 下面进行模型训练

# %% [markdown]
# 训练过程中的信息保存在work_dirs/experiments/experiments_name目录下
#
# training_samples保存了训练过程中达到不同迭代次数时的训练效果
#
# ckpt/experiments_name保存了训练过程中达到不同迭代次数时的模型权重文件

# %%
# 堡垒之夜(Fortnite)游戏画面 to 绝地求生(PUBG)游戏画面
# !bash tools/dist_train.sh configs/cyclegan/cyclegan_lsgan_resnet_in_facades_b1x1_80k_Fortnite2PUBG.py 1 --work-dir work_dirs/experiments/cyclegan_Fortnite2PUBG/
# Out:
# /home/wxy/miniconda3/envs/style/lib/python3.7/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# /home/wxy/miniconda3/envs/style/lib/python3.7/site-packages/mmcv/__init__.py:21: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
# ...
